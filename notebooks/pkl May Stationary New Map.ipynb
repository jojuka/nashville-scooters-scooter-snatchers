# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import datetime as dt
import math
import numpy as np
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
from folium.plugins import HeatMap
from shapely.geometry import Point
import geopandas as gpd
import matplotlib.pyplot as plt
import json

# %%
may = pd.read_csv('../data/may.csv/may.csv')

# %%
may.sumdgroup.unique()
# Out:
# array(['scooter', 'Scooter', 'bicycle'], dtype=object)

# %%
may_scooters = may.loc[may.sumdgroup.isin(['scooter', 'Scooter'])]

# %%
may_scooters = may_scooters[[ 'companyname', 'sumdid', 'chargelevel','pubdatetime', 'latitude', 'longitude']]

# %%
may_scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20283582 entries, 0 to 20292502
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   companyname  object
#  1   sumdid       object
#  2   chargelevel  float64
#  3   pubdatetime  object
#  4   latitude     float64
#  5   longitude    float64
# dtypes: float64(3), object(3)
# memory usage: 1.1+ GB

# %%
may_scooters.to_pickle("../data/may.pkl")

# %%
may_scooters.pubdatetime = pd.to_datetime(may_scooters.pubdatetime)

# %%
may_scooters.head()
# Out:
#   companyname        sumdid  chargelevel             pubdatetime   latitude  \
# 0        Bird  PoweredLIRL1         93.0 2019-05-01 00:01:41.247  36.136822
# 1        Bird  PoweredXWRWC         35.0 2019-05-01 00:01:41.247  36.191252
# 2        Bird  PoweredMEJEH         90.0 2019-05-01 00:01:41.247  36.144752
# 3        Bird  Powered1A7TC         88.0 2019-05-01 00:01:41.247  36.162056
# 4        Bird  Powered2TYEF         98.0 2019-05-01 00:01:41.247  36.150973
#
#    longitude
# 0 -86.799877
# 1 -86.772945
# 2 -86.806293
# 3 -86.774688
# 4 -86.783109

# %%
may_scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20283582 entries, 0 to 20292502
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   companyname  object
#  1   sumdid       object
#  2   chargelevel  float64
#  3   pubdatetime  datetime64[ns]
#  4   latitude     float64
#  5   longitude    float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 1.1+ GB

# %%
may_scooters['date'] = may_scooters['pubdatetime'].dt.date

# %%
may_scooters.date = pd.to_datetime(may_scooters.date)

# %% [markdown]
# To round down to closest 15, this should work
#
# 15 * math.floor(number/15)

# %%
may_scooters.isnull().sum()
# Out:
# companyname      0
# sumdid           0
# chargelevel    283
# pubdatetime      0
# latitude         0
# longitude        0
# date             0
# dtype: int64

# %%
may_scooters = may_scooters.dropna()

# %%
may_scooters
# Out:
#          companyname                                       sumdid  \
# 0               Bird                                 PoweredLIRL1
# 1               Bird                                 PoweredXWRWC
# 2               Bird                                 PoweredMEJEH
# 3               Bird                                 Powered1A7TC
# 4               Bird                                 Powered2TYEF
# ...              ...                                          ...
# 20292498        Jump  Poweredbb60ef04-c719-597f-805f-20978964fd8c
# 20292499        Jump  Powered9f5743ed-7f81-539b-9e37-6503d54445d3
# 20292500        Jump  Powered5744d1db-3bbe-55e5-9a23-a93828ba54fc
# 20292501        Jump  Poweredad1d6d3b-162a-5bec-bffd-cac4ac8dee1c
# 20292502        Jump  Powered8505008e-97c9-5003-8975-2ea6b2634fa0
#
#           chargelevel             pubdatetime   latitude  longitude       date
# 0                93.0 2019-05-01 00:01:41.247  36.136822 -86.799877 2019-05-01
# 1                35.0 2019-05-01 00:01:41.247  36.191252 -86.772945 2019-05-01
# 2                90.0 2019-05-01 00:01:41.247  36.144752 -86.806293 2019-05-01
# 3                88.0 2019-05-01 00:01:41.247  36.162056 -86.774688 2019-05-01
# 4                98.0 2019-05-01 00:01:41.247  36.150973 -86.783109 2019-05-01
# ...               ...                     ...        ...        ...        ...
# 20292498         49.0 2019-05-31 23:59:42.000  36.163900 -86.782300 2019-05-31
# 20292499         68.0 2019-05-31 23:59:42.000  36.160600 -86.776800 2019-05-31
# 20292500         53.0 2019-05-31 23:59:42.000  36.160600 -86.776900 2019-05-31
# 20292501         42.0 2019-05-31 23:59:42.000  36.162400 -86.774500 2019-05-31
# 20292502         76.0 2019-05-31 23:59:42.000  36.151900 -86.798500 2019-05-31
#
# [20283299 rows x 7 columns]

# %%
may_scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20283299 entries, 0 to 20292502
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   companyname  object
#  1   sumdid       object
#  2   chargelevel  float64
#  3   pubdatetime  datetime64[ns]
#  4   latitude     float64
#  5   longitude    float64
#  6   date         datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), object(2)
# memory usage: 1.2+ GB

# %%
may_scooters['date'] = may_scooters['pubdatetime'].dt.date

# %%
may_scooters['hour'] = may_scooters['pubdatetime'].dt.hour

# %%
may_scooters['minute'] = may_scooters['pubdatetime'].dt.minute

# %%
may_scooters.head()
# Out:
#   companyname        sumdid  chargelevel             pubdatetime   latitude  \
# 0        Bird  PoweredLIRL1         93.0 2019-05-01 00:01:41.247  36.136822
# 1        Bird  PoweredXWRWC         35.0 2019-05-01 00:01:41.247  36.191252
# 2        Bird  PoweredMEJEH         90.0 2019-05-01 00:01:41.247  36.144752
# 3        Bird  Powered1A7TC         88.0 2019-05-01 00:01:41.247  36.162056
# 4        Bird  Powered2TYEF         98.0 2019-05-01 00:01:41.247  36.150973
#
#    longitude        date  hour  minute
# 0 -86.799877  2019-05-01     0       1
# 1 -86.772945  2019-05-01     0       1
# 2 -86.806293  2019-05-01     0       1
# 3 -86.774688  2019-05-01     0       1
# 4 -86.783109  2019-05-01     0       1

# %%
may_scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20283299 entries, 0 to 20292502
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   companyname  object
#  1   sumdid       object
#  2   chargelevel  float64
#  3   pubdatetime  datetime64[ns]
#  4   latitude     float64
#  5   longitude    float64
#  6   date         object
#  7   hour         int64
#  8   minute       int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 1.5+ GB

# %%
may_scooters['roundedtime'] = may_scooters['minute'].apply(lambda x: 15*round(x/15))

# %%
may_scooters = may_scooters.round({'latitude': 3})

# %%
may_scooters = may_scooters.round({'longitude': 3})

# %%
may_scooters
# Out:
#          companyname                                       sumdid  \
# 0               Bird                                 PoweredLIRL1
# 1               Bird                                 PoweredXWRWC
# 2               Bird                                 PoweredMEJEH
# 3               Bird                                 Powered1A7TC
# 4               Bird                                 Powered2TYEF
# ...              ...                                          ...
# 20292498        Jump  Poweredbb60ef04-c719-597f-805f-20978964fd8c
# 20292499        Jump  Powered9f5743ed-7f81-539b-9e37-6503d54445d3
# 20292500        Jump  Powered5744d1db-3bbe-55e5-9a23-a93828ba54fc
# 20292501        Jump  Poweredad1d6d3b-162a-5bec-bffd-cac4ac8dee1c
# 20292502        Jump  Powered8505008e-97c9-5003-8975-2ea6b2634fa0
#
#           chargelevel             pubdatetime  latitude  longitude  \
# 0                93.0 2019-05-01 00:01:41.247    36.137    -86.800
# 1                35.0 2019-05-01 00:01:41.247    36.191    -86.773
# 2                90.0 2019-05-01 00:01:41.247    36.145    -86.806
# 3                88.0 2019-05-01 00:01:41.247    36.162    -86.775
# 4                98.0 2019-05-01 00:01:41.247    36.151    -86.783
# ...               ...                     ...       ...        ...
# 20292498         49.0 2019-05-31 23:59:42.000    36.164    -86.782
# 20292499         68.0 2019-05-31 23:59:42.000    36.161    -86.777
# 20292500         53.0 2019-05-31 23:59:42.000    36.161    -86.777
# 20292501         42.0 2019-05-31 23:59:42.000    36.162    -86.774
# 20292502         76.0 2019-05-31 23:59:42.000    36.152    -86.798
#
#                 date  hour  minute  roundedtime
# 0         2019-05-01     0       1            0
# 1         2019-05-01     0       1            0
# 2         2019-05-01     0       1            0
# 3         2019-05-01     0       1            0
# 4         2019-05-01     0       1            0
# ...              ...   ...     ...          ...
# 20292498  2019-05-31    23      59           60
# 20292499  2019-05-31    23      59           60
# 20292500  2019-05-31    23      59           60
# 20292501  2019-05-31    23      59           60
# 20292502  2019-05-31    23      59           60
#
# [20283299 rows x 10 columns]

# %%
agg_time_scooters = may_scooters.loc[:,["latitude", "longitude", "date", "hour", "roundedtime", "sumdid"]]\
    .groupby(["latitude", "longitude", "date", "hour", "roundedtime"])\
    .agg({"sumdid": pd.Series.nunique})\
    .reset_index()

# %%
agg_time_scooters.head()
# Out:
#    latitude  longitude        date  hour  roundedtime  sumdid
# 0       0.0        0.0  2019-05-01     0            0       1
# 1       0.0        0.0  2019-05-01     0           15       1
# 2       0.0        0.0  2019-05-01     0           30       1
# 3       0.0        0.0  2019-05-01     0           45       1
# 4       0.0        0.0  2019-05-01     0           60       1

# %%
agg_time_scooters.drop(agg_time_scooters.loc[agg_time_scooters['latitude']==0].index, inplace=True)

# %%
agg_time_scooters
# Out:
#          latitude  longitude        date  hour  roundedtime  sumdid
# 1051       32.789    -79.940  2019-05-28    20           30       1
# 1052       32.789    -79.940  2019-05-28    20           45       1
# 1053       32.789    -79.940  2019-05-28    20           60       1
# 1054       32.789    -79.940  2019-05-28    21            0       1
# 1055       32.789    -79.940  2019-05-28    21           15       1
# ...           ...        ...         ...   ...          ...     ...
# 2960838    36.617    -87.285  2019-05-22    10            0       1
# 2960839    36.617    -87.285  2019-05-22    10           15       1
# 2960840    36.617    -87.285  2019-05-22    10           30       1
# 2960841    36.617    -87.285  2019-05-22    10           45       1
# 2960842    36.617    -87.285  2019-05-22    10           60       1
#
# [2959792 rows x 6 columns]

# %%
agg_time_scooters.sort_values('sumdid', ascending = False).head(10)
# Out:
#        latitude  longitude        date  hour  roundedtime  sumdid
# 85303     36.12    -86.753  2019-05-26     9           30     475
# 85302     36.12    -86.753  2019-05-26     9           15     472
# 85304     36.12    -86.753  2019-05-26     9           45     471
# 85551     36.12    -86.753  2019-05-28    11            0     471
# 85422     36.12    -86.753  2019-05-27     9           15     470
# 85308     36.12    -86.753  2019-05-26    10           30     469
# 85549     36.12    -86.753  2019-05-28    10           45     469
# 85307     36.12    -86.753  2019-05-26    10           15     468
# 85309     36.12    -86.753  2019-05-26    10           45     468
# 85548     36.12    -86.753  2019-05-28    10           30     461

# %%
agg_time_scooters.drop(agg_time_scooters.loc[(agg_time_scooters['latitude']==36.12) & (agg_time_scooters['longitude'] == -86.753)].index, inplace=True)

# %%
agg_time_scooters.drop(agg_time_scooters.loc[(agg_time_scooters['latitude']==36.12) & (agg_time_scooters['longitude'] == -86.754)].index, inplace=True)

# %%
agg_time_scooters.sort_values('sumdid', ascending = False).head(10000)
# Out:
#          latitude  longitude        date  hour  roundedtime  sumdid
# 104091     36.121    -86.770  2019-05-29    18           15     130
# 104090     36.121    -86.770  2019-05-29    18            0     129
# 104088     36.121    -86.770  2019-05-29    17           45     129
# 104089     36.121    -86.770  2019-05-29    17           60     128
# 104087     36.121    -86.770  2019-05-29    17           30     128
# ...           ...        ...         ...   ...          ...     ...
# 1643926    36.157    -86.781  2019-05-13    18           60      30
# 1643925    36.157    -86.781  2019-05-13    18           45      30
# 1845721    36.160    -86.779  2019-05-30     0           30      30
# 1845723    36.160    -86.779  2019-05-30     0           60      30
# 1845724    36.160    -86.779  2019-05-30     1            0      30
#
# [10000 rows x 6 columns]

# %% [markdown]
# df= unique scooters, lat & long, date , hour, roundtime

# %%
agg_time_scooters.drop(agg_time_scooters.loc[agg_time_scooters['sumdid']>50].index, inplace=True)

# %%
agg_time_scooters.sort_values('sumdid', ascending = False)
# Out:
#          latitude  longitude        date  hour  roundedtime  sumdid
# 102476     36.121    -86.770  2019-05-16     7           15      50
# 101636     36.121    -86.771  2019-05-29     8           30      50
# 2099735    36.164    -86.769  2019-05-22    18           15      50
# 2099733    36.164    -86.769  2019-05-22    17           60      50
# 103887     36.121    -86.770  2019-05-28     1           30      50
# ...           ...        ...         ...   ...          ...     ...
# 1158005    36.151    -86.794  2019-05-04    16           45       1
# 1158004    36.151    -86.794  2019-05-04    16           30       1
# 1158003    36.151    -86.794  2019-05-04    15           60       1
# 1158002    36.151    -86.794  2019-05-04    15           45       1
# 2960842    36.617    -87.285  2019-05-22    10           60       1
#
# [2953466 rows x 6 columns]

# %%
agg_time_scooters.sort_values('sumdid', ascending = True)
# Out:
#          latitude  longitude        date  hour  roundedtime  sumdid
# 1051       32.789    -79.940  2019-05-28    20           30       1
# 1707549    36.158    -86.788  2019-05-19     5           45       1
# 1707548    36.158    -86.788  2019-05-19     5           30       1
# 1707536    36.158    -86.788  2019-05-19     3            0       1
# 1707522    36.158    -86.788  2019-05-19     0            0       1
# ...           ...        ...         ...   ...          ...     ...
# 103759     36.121    -86.770  2019-05-26    23           60      50
# 103758     36.121    -86.770  2019-05-26    23           45      50
# 1912392    36.161    -86.775  2019-05-26     4            0      50
# 102106     36.121    -86.770  2019-05-02     6           30      50
# 1905216    36.161    -86.777  2019-05-24    22           60      50
#
# [2953466 rows x 6 columns]

# %% [markdown]
# Create 2 dataframes: 1 weekends the other weekdays
# 1- reformat days to group
# 2

# %%
agg_time_scooters['date']=pd.to_datetime(agg_time_scooters.date)

# %%
agg_time_scooters['day_of_week'] = agg_time_scooters.date.dt.strftime("%w")

# %%
agg_time_scooters.head()
# Out:
#       latitude  longitude       date  hour  roundedtime  sumdid day_of_week
# 1051    32.789     -79.94 2019-05-28    20           30       1           2
# 1052    32.789     -79.94 2019-05-28    20           45       1           2
# 1053    32.789     -79.94 2019-05-28    20           60       1           2
# 1054    32.789     -79.94 2019-05-28    21            0       1           2
# 1055    32.789     -79.94 2019-05-28    21           15       1           2

# %%
agg_time_scooters['day_of_week'] = agg_time_scooters.day_of_week.astype(int)

# %%
weekend_scooters = agg_time_scooters[agg_time_scooters['day_of_week'].isin([6,0])]

# %%
weekday_scooters = agg_time_scooters[agg_time_scooters['day_of_week'].isin([1,2,3,4,5])]

# %%
weekend_scooters
# Out:
#          latitude  longitude       date  hour  roundedtime  sumdid  \
# 4505       35.865    -86.343 2019-05-18     0            0       1
# 4506       35.865    -86.343 2019-05-18     0           15       1
# 4507       35.865    -86.343 2019-05-18     0           30       1
# 4508       35.865    -86.343 2019-05-18     0           45       1
# 4509       35.865    -86.343 2019-05-18     0           60       1
# ...           ...        ...        ...   ...          ...     ...
# 2960686    36.330    -86.619 2019-05-26     2           30       1
# 2960687    36.335    -86.909 2019-05-18    21           45       1
# 2960688    36.335    -86.909 2019-05-18    21           60       1
# 2960709    36.380    -86.777 2019-05-05     3            0       1
# 2960710    36.380    -86.777 2019-05-05     3           15       1
#
#          day_of_week
# 4505               6
# 4506               6
# 4507               6
# 4508               6
# 4509               6
# ...              ...
# 2960686            0
# 2960687            6
# 2960688            6
# 2960709            0
# 2960710            0
#
# [747150 rows x 7 columns]

# %%
weekday_scooters
# Out:
#          latitude  longitude       date  hour  roundedtime  sumdid  \
# 1051       32.789    -79.940 2019-05-28    20           30       1
# 1052       32.789    -79.940 2019-05-28    20           45       1
# 1053       32.789    -79.940 2019-05-28    20           60       1
# 1054       32.789    -79.940 2019-05-28    21            0       1
# 1055       32.789    -79.940 2019-05-28    21           15       1
# ...           ...        ...        ...   ...          ...     ...
# 2960838    36.617    -87.285 2019-05-22    10            0       1
# 2960839    36.617    -87.285 2019-05-22    10           15       1
# 2960840    36.617    -87.285 2019-05-22    10           30       1
# 2960841    36.617    -87.285 2019-05-22    10           45       1
# 2960842    36.617    -87.285 2019-05-22    10           60       1
#
#          day_of_week
# 1051               2
# 1052               2
# 1053               2
# 1054               2
# 1055               2
# ...              ...
# 2960838            3
# 2960839            3
# 2960840            3
# 2960841            3
# 2960842            3
#
# [2206316 rows x 7 columns]

# %%
agg_time_scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2953466 entries, 1051 to 2960842
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   latitude     float64
#  1   longitude    float64
#  2   date         datetime64[ns]
#  3   hour         int64
#  4   roundedtime  int64
#  5   sumdid       int64
#  6   day_of_week  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3)
# memory usage: 169.0 MB

# %%
weekend_scooters['geometry'] = weekend_scooters.apply(lambda x: Point((x.longitude, 
                                                         x.latitude)), 
                                        axis=1)
weekend_scooters.head(3)
# Out:
# C:\Users\ferralme\AppData\Local\Temp/ipykernel_20716/1441982155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weekend_scooters['geometry'] = weekend_scooters.apply(lambda x: Point((x.longitude,
#       latitude  longitude       date  hour  roundedtime  sumdid  day_of_week  \
# 4505    35.865    -86.343 2019-05-18     0            0       1            6
# 4506    35.865    -86.343 2019-05-18     0           15       1            6
# 4507    35.865    -86.343 2019-05-18     0           30       1            6
#
#                     geometry
# 4505  POINT (-86.343 35.865)
# 4506  POINT (-86.343 35.865)
# 4507  POINT (-86.343 35.865)

# %%
weekend_scooters = gpd.GeoDataFrame(weekend_scooters, 
                           crs = 'EPSG:4326', 
                           geometry = weekend_scooters['geometry'])
weekend_scooters.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 747150 entries, 4505 to 2960710
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   latitude     747150 non-null  float64
#  1   longitude    747150 non-null  float64
#  2   date         747150 non-null  datetime64[ns]
#  3   hour         747150 non-null  int64
#  4   roundedtime  747150 non-null  int64
#  5   sumdid       747150 non-null  int64
#  6   day_of_week  747150 non-null  int32
#  7   geometry     747150 non-null  geometry
# dtypes: datetime64[ns](1), float64(2), geometry(1), int32(1), int64(3)
# memory usage: 48.5 MB

# %%
weekend_scooters['latitude'].isnull().count()
# Out:
# 747150

# %%
weekend_scooters.info()

# %%
type(weekend_scooters)
# Out:
# pandas.core.frame.DataFrame

# %%
zipcodes = gpd.read_file('../data/zipcodes.geojson')
print(zipcodes.crs)
zipcodes.head( )
# Out:
# epsg:4326
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37115        1    MADISON  178783.02488886821  596553400.57885742
# 1  37216        3  NASHVILLE  75820.997821400058  188884682.28344727
# 2  37204        9  NASHVILLE  93180.292250425613  200664795.51708984
# 3  37027       11  BRENTWOOD   159760.6942933173  174978422.04101562
# 4  37064       18   FRANKLIN  28995.828320601937  46969608.005737305
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...
# 1  MULTIPOLYGON (((-86.73451 36.23774, -86.73425 ...
# 2  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 3  MULTIPOLYGON (((-86.81258 36.06319, -86.81263 ...
# 4  MULTIPOLYGON (((-87.02197 36.01200, -87.02140 ...

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
weekend_scooters_may = gpd.GeoDataFrame(weekend_scooters, 
                           crs = zipcodes.crs, 
                           geometry = weekend_scooters['geometry'])

# %%
weekend_scooters_may.plot()
# Out:
# <AxesSubplot:>

# %%
type(weekend_scooters_may)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
zipcodes.plot()
# Out:
# <AxesSubplot:>

# %%
weekend_may_map = gpd.sjoin(weekend_scooters_may, zipcodes, op = 'within')

# %%
weekend_may_map.head()
# Out:
#       latitude  longitude       date  hour  roundedtime  sumdid  day_of_week  \
# 6753    36.010    -86.615 2019-05-11    11           45       1            6
# 6754    36.010    -86.615 2019-05-11    11           60       1            6
# 6802    36.011    -86.684 2019-05-26     5           30       2            0
# 6803    36.011    -86.684 2019-05-26     5           45       3            0
# 6804    36.011    -86.684 2019-05-26     5           60       3            0
#
#                         geometry  index_right    zip objectid    po_name  \
# 6753  POINT (-86.61500 36.01000)           50  37086        5  LA VERGNE
# 6754  POINT (-86.61500 36.01000)           50  37086        5  LA VERGNE
# 6802  POINT (-86.68400 36.01100)           51  37013       34    ANTIOCH
# 6803  POINT (-86.68400 36.01100)           51  37013       34    ANTIOCH
# 6804  POINT (-86.68400 36.01100)           51  37013       34    ANTIOCH
#
#           shape_stlength        shape_starea
# 6753  36883.570021719861  29699281.948913574
# 6754  36883.570021719861  29699281.948913574
# 6802  349164.88029162859  1150567551.5894165
# 6803  349164.88029162859  1150567551.5894165
# 6804  349164.88029162859  1150567551.5894165

# %%
area_center = [36.23245257407244, -86.77676762469858]

# %% [markdown]
# ax = weekend_may_map.plot(figsize = (8, 10), color = 'blue')
# weekend_scooters_may_map.plot( ax = ax, column = 'geometry');
# plt.show();

# %%
weekend_scooters_may_map = folium.Map(location =  area_center, zoom_start = 12)
weekend_scooters_may_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1a626a4a040f469cbba84128080977f4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1a626a4a040f469cbba84128080977f4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1a626a4a040f469cbba84128080977f4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1a626a4a040f469cbba84128080977f4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.23245257407244%2C%20-86.77676762469858%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# weekend_scooters_may['date'] = weekend_scooters_may.date.astype(object)

# %%
weekend_scooters
# Out:
#          latitude  longitude       date  hour  roundedtime  sumdid  \
# 4505       35.865    -86.343 2019-05-18     0            0       1
# 4506       35.865    -86.343 2019-05-18     0           15       1
# 4507       35.865    -86.343 2019-05-18     0           30       1
# 4508       35.865    -86.343 2019-05-18     0           45       1
# 4509       35.865    -86.343 2019-05-18     0           60       1
# ...           ...        ...        ...   ...          ...     ...
# 2960686    36.330    -86.619 2019-05-26     2           30       1
# 2960687    36.335    -86.909 2019-05-18    21           45       1
# 2960688    36.335    -86.909 2019-05-18    21           60       1
# 2960709    36.380    -86.777 2019-05-05     3            0       1
# 2960710    36.380    -86.777 2019-05-05     3           15       1
#
#          day_of_week                    geometry
# 4505               6  POINT (-86.34300 35.86500)
# 4506               6  POINT (-86.34300 35.86500)
# 4507               6  POINT (-86.34300 35.86500)
# 4508               6  POINT (-86.34300 35.86500)
# 4509               6  POINT (-86.34300 35.86500)
# ...              ...                         ...
# 2960686            0  POINT (-86.61900 36.33000)
# 2960687            6  POINT (-86.90900 36.33500)
# 2960688            6  POINT (-86.90900 36.33500)
# 2960709            0  POINT (-86.77700 36.38000)
# 2960710            0  POINT (-86.77700 36.38000)
#
# [747150 rows x 8 columns]

# %%
wknd_scoot_may = HeatMap(weekend_scooters['geometry']).add_to(weekend_scooters_may_map)
wknd_scoot_may
weekend_scooters_may_map.save("output.html")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20716/1480771841.py in <module>
# ----> 1 wknd_scoot_may = HeatMap(weekend_scooters['geometry']).add_to(weekend_scooters_may_map)
#       2 wknd_scoot_may
#       3 weekend_scooters_may_map.save("output.html")
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\folium\plugins\heat_map.py in __init__(self, data, name, min_opacity, max_zoom, max_val, radius, blur, gradient, overlay, control, show, **kwargs)
#      64         self._name = 'HeatMap'
#      65         data = if_pandas_df_convert_to_numpy(data)
# ---> 66         self.data = [[*validate_location(line[:2]), *line[2:]]  # noqa: E999
#      67                      for line in data]
#      68         if np.any(np.isnan(self.data)):
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\folium\plugins\heat_map.py in <listcomp>(.0)
#      64         self._name = 'HeatMap'
#      65         data = if_pandas_df_convert_to_numpy(data)
# ---> 66         self.data = [[*validate_location(line[:2]), *line[2:]]  # noqa: E999
#      67                      for line in data]
#      68         if np.any(np.isnan(self.data)):
#
# TypeError: 'Point' object is not subscriptable

# %%
display(wknd_scoot_may)

# %%
weekend_scooters.plot()
# Out:
# <AxesSubplot:>

# %%
wknd_scoot_may_fmc = folium.Map(location =  area_center, zoom_start = 12)

locations = weekend_scooters[['latitude','longitude']].values.tolist()
wknd_scoot_may_fmc.add_child(
    FastMarkerCluster(locations)
)
wknd_scoot_may_fmc
wknd_scoot_may_fmc.save("wknd_may.html")

# %%
wkdy_scoot_may_fmc = folium.Map(location =  area_center, zoom_start = 12)

locations = weekday_scooters[['latitude','longitude']].values.tolist()
wkdy_scoot_may_fmc.add_child(
    FastMarkerCluster(locations)
)
wkdy_scoot_may_fmc
wkdy_scoot_may_fmc.save("wkdy_may.html")

# %%
weekend_scooters.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 747150 entries, 4505 to 2960710
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   latitude     747150 non-null  float64
#  1   longitude    747150 non-null  float64
#  2   date         747150 non-null  datetime64[ns]
#  3   hour         747150 non-null  int64
#  4   roundedtime  747150 non-null  int64
#  5   sumdid       747150 non-null  int64
#  6   day_of_week  747150 non-null  int32
#  7   geometry     747150 non-null  geometry
# dtypes: datetime64[ns](1), float64(2), geometry(1), int32(1), int64(3)
# memory usage: 48.5 MB

# %%
wknd_scoot_may_c = folium.Map(location =  area_center, zoom_start = 12)
marker_cluster = MarkerCluster().add_to(wknd_scoot_may_c)
#folium.GeoJson.add_to(wknd_scoot_may_c)
for row_index, row_values in weekend_scooters.iterrows():
    loc = [row_values['latitude'], row_values['longitude']]
    pop = str(row_values['sumdid'])
    icon=folium.Icon(color="blue",icon="bus", prefix='fa')
    
    marker = folium.Marker(
        location = loc, 
        popup = pop,
    icon = icon) 
    
    marker.add_to(marker_cluster)
wknd_scoot_may_c.save("wknd_scoot.html")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20716/2487287071.py in <module>
#      13
#      14     marker.add_to(marker_cluster)
# ---> 15 wknd_scoot_may_c.save("wknd_scoot.html")
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\branca\element.py in save(self, outfile, close_file, **kwargs)
#     165
#     166         root = self.get_root()
# --> 167         html = root.render(**kwargs)
#     168         fid.write(html.encode('utf8'))
#     169         if close_file:
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\branca\element.py in render(self, **kwargs)
#     317         """Renders the HTML representation of the element."""
#     318         for name, child in self._children.items():
# --> 319             child.render(**kwargs)
#     320         return self._template.render(this=self, kwargs=kwargs)
#     321
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\folium\folium.py in render(self, **kwargs)
#     368             '</style>'), name='map_style')
#     369
# --> 370         super(Map, self).render(**kwargs)
#     371
#     372     def fit_bounds(self, bounds, padding_top_left=None,
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\branca\element.py in render(self, **kwargs)
#     641
#     642         for name, element in self._children.items():
# --> 643             element.render(**kwargs)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\folium\plugins\marker_cluster.py in render(self, **kwargs)
#      82
#      83     def render(self, **kwargs):
# ---> 84         super(MarkerCluster, self).render(**kwargs)
#      85
#      86         figure = self.get_root()
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\branca\element.py in render(self, **kwargs)
#     641
#     642         for name, element in self._children.items():
# --> 643             element.render(**kwargs)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\branca\element.py in render(self, **kwargs)
#     641
#     642         for name, element in self._children.items():
# --> 643             element.render(**kwargs)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\folium\map.py in render(self, **kwargs)
#     366                                             'if it is not in a Figure.')
#     367
# --> 368         figure.script.add_child(Element(
#     369             self._template.render(this=self, kwargs=kwargs)),
#     370             name=self.get_name())
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\branca\element.py in __init__(self, template, template_name)
#      57
#      58         if template is not None:
# ---> 59             self._template = Template(template)
#      60         elif template_name is not None:
#      61             self._template = ENV.get_template(template_name)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in __new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#    1206             enable_async,
#    1207         )
# -> 1208         return env.from_string(source, template_class=cls)
#    1209
#    1210     @classmethod
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in from_string(self, source, globals, template_class)
#    1090         gs = self.make_globals(globals)
#    1091         cls = template_class or self.template_class
# -> 1092         return cls.from_code(self, self.compile(source), gs, None)
#    1093
#    1094     def make_globals(
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in compile(self, source, name, filename, raw, defer_init)
#     747             if isinstance(source, str):
#     748                 source_hint = source
# --> 749                 source = self._parse(source, name, filename)
#     750             source = self._generate(source, name, filename, defer_init=defer_init)
#     751             if raw:
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in _parse(self, source, name, filename)
#     604     ) -> nodes.Template:
#     605         """Internal parsing function used by `parse` and `compile`."""
# --> 606         return Parser(self, source, name, filename).parse()
#     607
#     608     def lex(
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\jinja2\parser.py in __init__(self, environment, source, name, filename, state)
#      65             str, t.Callable[["Parser"], t.Union[nodes.Node, t.List[nodes.Node]]]
#      66         ] = {}
# ---> 67         for extension in environment.iter_extensions():
#      68             for tag in extension.tags:
#      69                 self.extensions[tag] = extension.parse
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in iter_extensions(self)
#     446     def iter_extensions(self) -> t.Iterator["Extension"]:
#     447         """Iterates over the extensions by priority."""
# --> 448         return iter(sorted(self.extensions.values(), key=lambda x: x.priority))
#     449
#     450     def getitem(
#
# KeyboardInterrupt:

# %% [markdown]
# for ind, row in agg_time_scooters.iterrows():
#     print('working on row: ', ind)
#     if row['day_of_week'] >= 5:
#         agg_time_scooters.loc[ind, 'Week_part'] = 'Weekend'
#     elif row['day_of_week'] <= 5:
#         agg_time_scooters.loc[ind, 'day_of_week'] ='Weekday'
#     else:
#         agg_time_scooters.loc[ind, 'day_of_week'] ='NA'
# print('finished!')

# %% [markdown]
# pivot = pd.pivot_table(may_scooters, values = 'sumdid', index ='roundedtime', aggfunc =pd.Series.nunique)
# pivot

# %% [markdown]
# may_scooters.companyname.value_counts()

# %% [markdown]
# may_scooters = may_scooters[['sumdid', 'companyname','date','time','latitude', 'longitude', 'chargelevel']]

# %% [markdown]
# bird_scooters_may = may_scooters.loc[may_scooters['companyname'] == 'Bird'].sum()
# df.pivot(index='foo', columns='bar', values='baz')

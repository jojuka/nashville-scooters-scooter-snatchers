# %%
import pandas as pd
import pickle

# %%
# %%time
may = pd.read_csv('../data/may.csv')
may.head()
# Out:
# Wall time: 16.1 s
#                   pubdatetime   latitude  longitude        sumdid sumdtype  \
# 0  2019-05-01 00:01:41.247000  36.136822 -86.799877  PoweredLIRL1  Powered
# 1  2019-05-01 00:01:41.247000  36.191252 -86.772945  PoweredXWRWC  Powered
# 2  2019-05-01 00:01:41.247000  36.144752 -86.806293  PoweredMEJEH  Powered
# 3  2019-05-01 00:01:41.247000  36.162056 -86.774688  Powered1A7TC  Powered
# 4  2019-05-01 00:01:41.247000  36.150973 -86.783109  Powered2TYEF  Powered
#
#    chargelevel sumdgroup  costpermin companyname
# 0         93.0   scooter         0.0        Bird
# 1         35.0   scooter         0.0        Bird
# 2         90.0   scooter         0.0        Bird
# 3         88.0   scooter         0.0        Bird
# 4         98.0   scooter         0.0        Bird

# %%
may.info() ##20292503 rows, 9 columns, note pubdatetime is an object and needs to be changed to datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20292503 entries, 0 to 20292502
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  object
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   sumdtype     object
#  5   chargelevel  float64
#  6   sumdgroup    object
#  7   costpermin   float64
#  8   companyname  object
# dtypes: float64(4), object(5)
# memory usage: 1.4+ GB

# %%
may.isnull().sum()##CHARGE LEVEL COLUMN HAS 283 NULLS
# Out:
# pubdatetime      0
# latitude         0
# longitude        0
# sumdid           0
# sumdtype         0
# chargelevel    283
# sumdgroup        0
# costpermin       0
# companyname      0
# dtype: int64

# %%
##may.info()

# %%
##may.describe()

# %%
may.companyname.unique()
# Out:
# array(['Bird', 'Lyft', 'Gotcha', 'Lime', 'Spin', 'Jump', 'Bolt'],
#       dtype=object)

# %%
company_dict = {'Bird':'Bi', 'Lyft': 'Ly', 'Gotcha': 'G', 'Lime': 'Li', 'Spin': 'S', 'Jump': 'J', 'Bolt': 'Bo'}

# %%
may.companyname = may.companyname.replace(company_dict)##replaced company name with 2 letter name dictionary

# %%
##may.pubdatetime = pd.to_datetime(may.pubdatetime)##CHANGES PUBDATETIME COLUMN FROM OBJECT TO DATE TIME
may.pubdatetime = pd.to_datetime(may.pubdatetime)

# %%
##may.date=pd.to_datetime(may.pubdatetime).dt.date

# %%
may['year'] = may['pubdatetime'].dt.year

may['month'] = may['pubdatetime'].dt.month

may['day'] = may['pubdatetime'].dt.day

may['hour'] = may['pubdatetime'].dt.hour
may['min'] = may['pubdatetime'].dt.minute
##may['sec'] = may['pubdatetime'].dt.seconds

# %%
##import datetime
##from datetime import datetime
##my_date = datetime.strptime(pubdatetime, "%Y-%m-%d")
##my_date
##may['date'] = [d.date() for d in may['pubdatetime']]
##may['time'] = [d.time() for d in may['pubdatetime']]

##import datetime

# this line converts the string object in Timestamp object
##may['DateTime'] = [datetime.datetime.strptime(d, "%Y-%m-%d %H:%M") for d in may["pubdatetime"]]

# extracting date from timestamp
##may['Date'] = [datetime.datetime.date(d) for d in may['pubdatetime']] 

# extracting time from timestamp
##may['Time'] = [datetime.datetime.time(d) for d in may['pubdatetime']]

# %%
may.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20292503 entries, 0 to 20292502
# Data columns (total 14 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  datetime64[ns]
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   sumdtype     object
#  5   chargelevel  float64
#  6   sumdgroup    object
#  7   costpermin   float64
#  8   companyname  object
#  9   year         int64
#  10  month        int64
#  11  day          int64
#  12  hour         int64
#  13  min          int64
# dtypes: datetime64[ns](1), float64(4), int64(5), object(4)
# memory usage: 2.1+ GB

# %%
may.sumdgroup.unique() ##produces all the unique values in the sumdgroup column
# Out:
# array(['scooter', 'Scooter', 'bicycle'], dtype=object)

# %%
may.sumdtype.unique() ##produces all the unique values in the sumdtype column
# Out:
# array(['Powered', 'Standard'], dtype=object)

# %%
may_scooters = may.loc[may.sumdgroup.isin(['scooter', 'Scooter'])] ##FILTERS DATAFRAME TO ONLY SHOW ROWS WHERE SUMDGROUP = SCOOTERS

# %%
may_scooters.companyname.value_counts() ##gives the count of scooters by company
# Out:
# Li    7111655
# Bi    4334006
# Ly    3112581
# J     2984630
# S     1301001
# G      915314
# Bo     524395
# Name: companyname, dtype: int64

# %%
##may_scooters = may_scooters[['pubdatetime', 'latitude', 'longitude', 'chargelevel', 'companyname']] ##drops columns costpermin from dataframe

# %%
may_scooters = may.drop(columns=['costpermin']) ##drops columns chargelevel and costpermin from dataframe

# %%
may_scooters.dropna(inplace=True) ##dropping all null rows

# %%
may_scooters.tail(30)
# Out:
#                      pubdatetime   latitude  longitude  \
# 20292473 2019-05-31 23:58:27.240  36.120970 -86.776146
# 20292474 2019-05-31 23:58:27.240  36.129974 -86.780385
# 20292475 2019-05-31 23:58:27.240  36.124556 -86.788822
# 20292476 2019-05-31 23:58:27.240  36.127037 -86.777519
# 20292477 2019-05-31 23:58:27.240  36.129797 -86.775474
# 20292478 2019-05-31 23:58:27.240  36.126900 -86.777635
# 20292479 2019-05-31 23:58:27.240  36.126730 -86.778222
# 20292480 2019-05-31 23:58:27.240  36.127732 -86.789159
# 20292481 2019-05-31 23:58:27.240  36.125782 -86.788864
# 20292482 2019-05-31 23:58:27.240  36.127703 -86.789172
# 20292483 2019-05-31 23:58:27.240  36.126457 -86.789675
# 20292484 2019-05-31 23:58:27.240  36.126391 -86.775422
# 20292485 2019-05-31 23:58:27.240  36.132976 -86.798867
# 20292486 2019-05-31 23:58:27.243  36.121644 -86.775497
# 20292487 2019-05-31 23:58:27.243  36.122967 -86.776069
# 20292488 2019-05-31 23:58:27.243  36.109752 -86.765515
# 20292489 2019-05-31 23:58:27.243  36.115655 -86.764993
# 20292490 2019-05-31 23:58:27.243  36.109843 -86.765417
# 20292491 2019-05-31 23:58:27.243  36.115631 -86.764978
# 20292492 2019-05-31 23:58:27.243  36.108510 -86.764921
# 20292493 2019-05-31 23:58:27.243  36.122375 -86.775722
# 20292494 2019-05-31 23:58:27.243  36.121613 -86.775351
# 20292495 2019-05-31 23:58:27.243  36.120440 -86.777199
# 20292496 2019-05-31 23:58:27.243  36.121584 -86.775493
# 20292497 2019-05-31 23:58:43.000  36.147400 -86.811700
# 20292498 2019-05-31 23:59:42.000  36.163900 -86.782300
# 20292499 2019-05-31 23:59:42.000  36.160600 -86.776800
# 20292489   scooter          Li  2019      5   31    23   58
# 20292490   scooter          Li  2019      5   31    23   58
# 20292491   scooter          Li  2019      5   31    23   58
# 20292492   scooter          Li  2019      5   31    23   58
# 20292493   scooter          Li  2019      5   31    23   58
# 20292494   scooter          Li  2019      5   31    23   58
# 20292495   scooter          Li  2019      5   31    23   58
# 20292496   scooter          Li  2019      5   31    23   58
# 20292497   scooter           J  2019      5   31    23   58
# 20292498   scooter           J  2019      5   31    23   59
# 20292499   scooter           J  2019      5   31    23   59
# 20292500   scooter           J  2019      5   31    23   59
# 20292501   scooter           J  2019      5   31    23   59
# 20292502   scooter           J  2019      5   31    23   59

# %%
may_scooters.info()
##Original info before drop of null rows, RangeIndex: 20292503 entries, 0 to 20292502, Data columns (total 9 columns):
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20292220 entries, 0 to 20292502
# Data columns (total 13 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  datetime64[ns]
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   sumdtype     object
#  5   chargelevel  float64
#  6   sumdgroup    object
#  7   companyname  object
#  8   year         int64
#  9   month        int64
#  10  day          int64
#  11  hour         int64
#  12  min          int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(4)
# memory usage: 2.1+ GB

# %%
may_scooters.to_pickle("../data/may.pkl")

# %%
# %%time
may_test = pd.read_pickle("../data/may.pkl")
# Out:
# Wall time: 5.3 s

# %%
may_scooters.sumdid.unique()
# Out:
# array(['PoweredLIRL1', 'PoweredXWRWC', 'PoweredMEJEH', ...,
#        'PoweredS26HB', 'PoweredWVFVTYLWIVLI7', 'Powered6Y1U7'],
#       dtype=object)

# %%
may_scooters.sumdid.nunique() ##count the number of unique sumdid
# Out:
# 8302

# %%
print(may_scooters['sumdid'].value_counts()) ##the count of each of the distinct values of a specific column
##https://datascienceparichay.com/article/pandas-count-of-unique-values-in-each-column/
# Out:
# PoweredIE7H5RIN474PE     8921
# StandardNW5HJFO4R32LY    8921
# PoweredUK65LOU3K5N7G     8748
# PoweredIOHG2G3XKATUL     8576
# PoweredJCKMQCAL2SSNJ     8521
#                          ...
# PoweredGJYGPDVTFXRH7        1
# PoweredYEBSU                1
# PoweredCW742BQMJ3XHN        1
# PoweredCI6VKIK2KOFMC        1
# PoweredN4YI2A7RXZQLY        1
# Name: sumdid, Length: 8302, dtype: int64

# %%
##7 SCOOTER COMPANIES, 8304 SCOOTERS,

# %%
may_group=may_scooters.groupby(['companyname'])['sumdid'].nunique()

# %%
may_group
# Out:
# companyname
# Bi    3064
# Bo     346
# G      223
# J      976
# Li    1632
# Ly    1376
# S      685
# Name: sumdid, dtype: int64

# %%
##may_scooters.plot()
# Out:
# <AxesSubplot:>
# Error in callback <function flush_figures at 0x000002528C104040> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     251
#     252     if 'png' in formats:
# --> 253         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     254     if 'retina' in formats or 'png2x' in formats:
#     255         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     135         FigureCanvasBase(fig)
#     136
# --> 137     fig.canvas.print_figure(bytes_io, **kw)
#     138     data = bytes_io.getvalue()
#     139     if fmt == 'svg':
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2193                         self.figure.draw(renderer)
#    2194
# -> 2195                     bbox_inches = self.figure.get_tightbbox(
#    2196                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2197                     if pad_inches is None:
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2513                 # need this conditional....
#    2514                 try:
# -> 2515                     bbox = ax.get_tightbbox(
#    2516                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2517                 except TypeError:
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4201                     # this artist
#    4202                     continue
# -> 4203             bbox = a.get_tightbbox(renderer)
#    4204             if (bbox is not None
#    4205                     and 0 < bbox.width < np.inf
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\legend.py in get_tightbbox(self, renderer)
#     912             The bounding box in figure pixel coordinates.
#     913         """
# --> 914         return self._legend_box.get_window_extent(renderer)
#     915
#     916     def get_frame_on(self):
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\offsetbox.py in get_window_extent(self, renderer)
#     345         """Return the bounding box (`.Bbox`) in display space."""
#     346         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
# --> 347         px, py = self.get_offset(w, h, xd, yd, renderer)
#     348         return mtransforms.Bbox.from_bounds(px - xd, py - yd, w, h)
#     349
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\offsetbox.py in get_offset(self, width, height, xdescent, ydescent, renderer)
#     284
#     285         """
# --> 286         return (self._offset(width, height, xdescent, ydescent, renderer)
#     287                 if callable(self._offset)
#     288                 else self._offset)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\legend.py in _findoffset(self, width, height, xdescent, ydescent, renderer)
#     573
#     574         if self._loc == 0:  # "best".
# --> 575             x, y = self._find_best_position(width, height, renderer)
#     576         elif self._loc in Legend.codes.values():  # Fixed location.
#     577             bbox = Bbox.from_bounds(0, 0, width, height)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\legend.py in _find_best_position(self, width, height, renderer, consider)
#    1046             # XXX TODO: If markers are present, it would be good to take them
#    1047             # into account when checking vertex overlaps in the next line.
# -> 1048             badness = (sum(legendBox.count_contains(line.vertices)
#    1049                            for line in lines)
#    1050                        + legendBox.count_contains(offsets)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\legend.py in <genexpr>(.0)
#    1046             # XXX TODO: If markers are present, it would be good to take them
#    1047             # into account when checking vertex overlaps in the next line.
# -> 1048             badness = (sum(legendBox.count_contains(line.vertices)
#    1049                            for line in lines)
#    1050                        + legendBox.count_contains(offsets)
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\matplotlib\transforms.py in count_contains(self, vertices)
#     600         vertices = np.asarray(vertices)
#     601         with np.errstate(invalid='ignore'):
# --> 602             return (((self.min < vertices) &
#     603                      (vertices < self.max)).all(axis=1).sum())
#     604
#
# ~\Anaconda3\envs\geospatial\lib\site-packages\numpy\core\_methods.py in _all(a, axis, dtype, out, keepdims, where)
#      61     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      62     if where is True:
# ---> 63         return umr_all(a, axis, dtype, out, keepdims)
#      64     return umr_all(a, axis, dtype, out, keepdims, where=where)
#      65
#
# KeyboardInterrupt:

# %%
##import matplotlib.pyplot as plt
##import seaborn as sns
##%matplotlib inline

# %%
#set the seaborn theme, style, color palette
#sns.set(style="ticks", color_codes=True)

#make a correlation plot that looks at each variables relationship with every other variable
#and plots the distribution of each variable along the diagonal
#sns.pairplot(may_scooters);

# %%
duplicate_rows = may_scooters[may_scooters.duplicated()]
## Select duplicate rows except first occurrence based on all columns
##duplicateRowsDF = dfObj[dfObj.duplicated()]
##print("Duplicate Rows except first occurrence based on all columns are :")
##print(duplicateRowsDF)

# %%
print("Duplicate Rows except first occurrence based on all columns are:")
# Out:
# Duplicate Rows except first occurrence based on all columns are:

# %%
print(duplicate_rows)
# Out:
# 18839656 2019-05-30 14:15:57.053  36.162352 -86.774037  Powered406  Powered
#
#           chargelevel sumdgroup companyname  year  month  day  hour  min
# 1077              0.0   Scooter           G  2019      5    1     0    4
# 3427              0.0   Scooter           G  2019      5    1     0    9
# 5498              0.0   Scooter           G  2019      5    1     0   14
# 7752              0.0   Scooter           G  2019      5    1     0   19
# 9931              0.0   Scooter           G  2019      5    1     0   24
# ...               ...       ...         ...   ...    ...  ...   ...  ...
# 18824347          0.0   Scooter           G  2019      5   30    13   55
# 18828158          0.0   Scooter           G  2019      5   30    14    0
# 18831987          0.0   Scooter           G  2019      5   30    14    5
# 18835706          0.0   Scooter           G  2019      5   30    14   10
# 18839656          0.0   Scooter           G  2019      5   30    14   15
#
# [868 rows x 13 columns]

# %%
# Select all duplicate rows based on multiple column names in list
duplicate_location = Powered406[Powered406.duplicated(['latitude', 'longitude'])]

# %%
duplicate_location ##in Powered406 there are 868 rows. when looking at duplicate locations for Powered406 662 rows
# Out:
#                      pubdatetime   latitude  longitude      sumdid sumdtype  \
# 3427     2019-05-01 00:09:48.257  36.162910 -86.776332  Powered406  Powered
# 5498     2019-05-01 00:14:48.537  36.162910 -86.776332  Powered406  Powered
# 7752     2019-05-01 00:19:48.763  36.162910 -86.776332  Powered406  Powered
# 9931     2019-05-01 00:24:49.147  36.162910 -86.776332  Powered406  Powered
# 12097    2019-05-01 00:29:49.140  36.162910 -86.776332  Powered406  Powered
# ...                          ...        ...        ...         ...      ...
# 18824347 2019-05-30 13:55:56.267  36.162352 -86.774037  Powered406  Powered
# 18828158 2019-05-30 14:00:56.367  36.162352 -86.774037  Powered406  Powered
# 18831987 2019-05-30 14:05:56.797  36.162352 -86.774037  Powered406  Powered
# 18835706 2019-05-30 14:10:56.923  36.162352 -86.774037  Powered406  Powered
# 18839656 2019-05-30 14:15:57.053  36.162352 -86.774037  Powered406  Powered
#
#           chargelevel sumdgroup companyname  year  month  day  hour  min
# 3427              0.0   Scooter           G  2019      5    1     0    9
# 5498              0.0   Scooter           G  2019      5    1     0   14
# 7752              0.0   Scooter           G  2019      5    1     0   19
# 9931              0.0   Scooter           G  2019      5    1     0   24
# 12097             0.0   Scooter           G  2019      5    1     0   29
# ...               ...       ...         ...   ...    ...  ...   ...  ...
# 18824347          0.0   Scooter           G  2019      5   30    13   55
# 18828158          0.0   Scooter           G  2019      5   30    14    0
# 18831987          0.0   Scooter           G  2019      5   30    14    5
# 18835706          0.0   Scooter           G  2019      5   30    14   10
# 18839656          0.0   Scooter           G  2019      5   30    14   15
#
# [662 rows x 13 columns]

# %%
grouped_multiple=may_scooters.groupby(['latitude', 'longitude'])['sumdid'].nunique()

# %%
##may_group=may_scooters.groupby(['companyname'])['sumdid'].nunique()

# %%
grouped_multiple
# Out:
# latitude   longitude
# 0.000000    0.000000     18
# 32.789116  -79.940267     1
# 32.828031  -79.954386     1
# 32.859748  -79.992988     1
# 33.315812  -80.544998     1
#                          ..
# 36.616640  -87.284660     1
#            -87.284570     1
# 36.616650  -87.284660     1
# 36.616670  -87.284640     1
# 36.616700  -87.284640     1
# Name: sumdid, Length: 6942841, dtype: int64

# %% [markdown]
# # This notebook is for eda on the June trip data

# %% [markdown]
# #### Import needed modules

# %%
import pandas as pd

# %% [markdown]
# #### Import .csv to DataFrame and check top and bottom of the data

# %%
june_trip_df = pd.read_csv('../data/june_trip.csv')
june_trip_df.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-06-01 00:05:46.817000        Bird       BRD3572  PoweredSPI1T
# 1  2019-06-01 00:05:46.817000        Bird       BRD3571  Powered2I3MS
# 2         2019-06-01 00:09:54      Gotcha          GOT1    Powered327
# 3  2019-06-01 00:10:46.957000        Bird       BRD3610  Powered8U1A6
# 4  2019-06-01 00:10:46.957000        Bird       BRD3612  PoweredSPI1T
#
#    tripDuration  tripDistance            startDate        startTime  \
# 0           4.0    328.084000  2019-06-01 00:00:00  00:02:18.203333
# 1           5.0   4921.260000  2019-06-01 00:00:00  00:02:44.803333
# 2          12.0     12.426575  2019-06-01 00:00:00         00:09:56
# 3           2.0      0.000000  2019-06-01 00:00:00  00:10:31.163333
# 4           5.0    656.168000  2019-06-01 00:00:00  00:07:21.430000
#
#                endDate          endTime  startLatitude  startLongitude  \
# ...

# %%
june_trip_df.tail()
# Out:
#                pubTimeStamp companyName tripRecordNum  \
# 205622  2019-07-01 19:58:07        JUMP         JMP56
# 205623  2019-07-01 19:58:07        JUMP         JMP53
# 205624  2019-07-01 19:58:07        JUMP         JMP52
# 205625  2019-07-01 19:58:07        JUMP         JMP54
# 205626  2019-07-01 19:58:07        JUMP         JMP50
#
#                                              sumdID  tripDuration  \
# 205622  Powered2c1eeca5-26f4-5283-bbcd-5f46b19b7681        1440.0
# 205623  Poweredac7200ea-c5a4-5362-94a8-03e4d2255104        1440.0
# 205624  Powered3f96a82d-9641-58b6-b6db-b80f746a24cd        1440.0
# 205625  Poweredc2d0a425-86dd-5664-a036-d770559391bb        1440.0
# 205626  Powered1b56f557-adce-5c68-a98b-ab1ef41c7dcc        1440.0
#
#         tripDistance            startDate startTime              endDate  \
# 205622       40708.8  2019-06-30 00:00:00  02:16:21  2019-07-01 00:00:00
# 205623       36854.4  2019-06-29 00:00:00  21:46:34  2019-07-01 00:00:00
# ...

# %% [markdown]
# #### Check column attributes

# %%
june_trip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205627 entries, 0 to 205626
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    205627 non-null  object
#  1   companyName     205627 non-null  object
#  2   tripRecordNum   205627 non-null  object
#  3   sumdID          205627 non-null  object
#  4   tripDuration    205627 non-null  float64
#  5   tripDistance    205627 non-null  float64
#  6   startDate       205627 non-null  object
#  7   startTime       205627 non-null  object
#  8   endDate         205627 non-null  object
#  9   endTime         205627 non-null  object
#  10  startLatitude   205627 non-null  float64
#  11  startLongitude  205627 non-null  float64
#  12  endLatitude     205627 non-null  float64
#  13  endLongitude    205627 non-null  float64
#  14  tripRoute       205627 non-null  object
#  15  create_dt       205627 non-null  object
# dtypes: float64(6), object(10)
# ...

# %%
june_trip_df.isnull().sum()
# Out:
# pubTimeStamp      0
# companyName       0
# tripRecordNum     0
# sumdID            0
# tripDuration      0
# tripDistance      0
# startDate         0
# startTime         0
# endDate           0
# endTime           0
# startLatitude     0
# startLongitude    0
# endLatitude       0
# endLongitude      0
# tripRoute         0
# create_dt         0
# dtype: int64

# %%
june_trip_df.companyName.value_counts()
# Out:
# Lime             84728
# Bird             55014
# Lyft             37821
# SPIN             14294
# Bolt Mobility    10219
# Gotcha            1803
# JUMP              1748
# Name: companyName, dtype: int64

# %%
june_trip_df.sumdID.nunique()
# Out:
# 6742

# %%
june_trip_df.describe()
# Out:
#         tripDuration  tripDistance  startLatitude  startLongitude  \
# count  205627.000000  2.056270e+05  205627.000000   205627.000000
# mean       81.454936  5.254084e+03      36.156242      -86.784564
# std       431.513564  4.370924e+04       0.012074        0.013882
# min        -8.003717 -5.157480e+05      36.042892      -86.917893
# 25%         5.000000  9.481628e+02      36.150659      -86.792074
# 50%        10.000000  3.323491e+03      36.157100      -86.782000
# 75%        20.000000  6.952015e+03      36.163040      -86.776493
# max     11836.000000  1.848950e+07      36.300029      -86.602127
#
#          endLatitude   endLongitude
# count  205627.000000  205627.000000
# mean       36.156277     -86.784505
# std         0.169490       0.608159
# min       -36.850405    -122.428964
# 25%        36.150858     -86.792100
# 50%        36.157572     -86.781700
# 75%        36.163067     -86.776380
# max        47.613101     174.764886
